# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generating sample data
y = ['Roof', 'L14', 'L13', 'L12', 'L11', 'L10', 'L9', 'L8', 'L7', 'L6', 'L5', 'L4', 'L3', 'L2', 'L1', 'Mezzanine', 'GF', 'B01', 'B02']
x = [-5479.11, -7465.33, -10484.5, -12586, -14771, -16393, -18006.7, -19182.2, -20041.4, -20845.9, -21713.4, -22239.2, -22576.6, -22763.1, -27908.3, -27964.4, -23489, -23505.3, -23509.2]
reversed_x = list(reversed(x))
reversed_y = list(reversed(y))

# %%
plt.figure(figsize=(6,9))  # creates a new figure with specified size
plt.scatter(reversed_x, reversed_y)  # scatter plot

# Setting the labels for x and y axis
plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')

# z = np.polyfit(x, y, 1)  # Degree 1 (linear fit)
# p = np.poly1d(z)  # Create a function based on the fit
# plt.plot(x, p(x), "r--")  # Plot the trendline

plt.plot(x, y, "r-")

plt.gca().invert_xaxis()

# Setting the title for the graph
plt.title('Scatter plot')

plt.show()  # displays the figure
